# %% [markdown]
# Assignment Set 1 by [Fateme Rahimi](https://github.com/ftmhrahimi/Deep_Learning_F20_Assignments) for [Deep Learing](https://github.com/hhaji/Deep-Learning) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import tensorflow as tf
import torch

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.23.1
# TensorFlow Version:  2.1.0
# PyTorch Version:  1.6.0

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0 -0.154752  1.711262 -0.246886 -0.806889  0.297904
# 1  0.025354  0.652232 -1.201404  0.611745 -0.648811
# 2 -0.142268 -0.066370 -0.835366 -0.664922 -1.746687
# 3 -0.376091  2.067330  0.923894  1.848613  1.595771
# 4  0.201342  0.012389 -0.995226  0.717058 -1.255975
# 5  1.564087  0.382901 -1.375799 -1.202319  0.353852
# 6 -1.098658  0.581013  0.101924  0.041296  0.029577
# 7 -2.006937 -1.568347 -1.501124  0.150151 -0.538934
# 8 -0.937577  0.143359 -1.020793 -0.027814 -0.814331
# 9 -1.028076  0.505987  0.575743  0.405119  1.364846
#
# -> Execution Time = 27.960599422454834 in Seconds <-
